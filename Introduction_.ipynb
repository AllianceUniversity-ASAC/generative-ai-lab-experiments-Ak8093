# %%
a = 5
b = 3
sum = a + b
print("Sum:", sum)
# Out:
# Sum: 8

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 4
b = 6
product = a * b
print("Product:", product)
# Out:
# Product: 24

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
total = num1 + num2
print("Total:", total)
# Out:
# Enter first number: 22
# Enter second number: 23
# Total: 45

# %%
n = int(input("Enter a number: "))
total_sum = 0

for i in range(1, n+1):
    total_sum += i

print("Sum of numbers from 1 to", n, "is:", total_sum)
# Out:
# Enter a number: 6
# Sum of numbers from 1 to 6 is: 21

# %%
numbers = [10, 20, 30, 40, 50]
list_total = sum(numbers)
print("Sum of list elements:", list_total)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1867291273.py in <cell line: 0>()
#       1 numbers = [10, 20, 30, 40, 50]
# ----> 2 list_total = sum(numbers)
#       3 print("Sum of list elements:", list_total)
#
# TypeError: 'int' object is not callable

# %%
fruits = ["apple", "banana", "mango"]
fruits.append("orange")
print("Updated list:", fruits)
# Out:
# Updated list: ['apple', 'banana', 'mango', 'orange']
